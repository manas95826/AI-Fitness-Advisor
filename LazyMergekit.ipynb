# %% [markdown]
# <a href="https://colab.research.google.com/github/manas95826/AI-Fitness-Advisor/blob/main/LazyMergekit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🥱 LazyMergekit
#
# > 🗣️ [Large Language Model Course](https://github.com/mlabonne/llm-course)
#
# ❤️ Created by [@maximelabonne](https://twitter.com/maximelabonne).
#
# This notebook allows you to easily merge multiple models using [mergekit](https://github.com/cg123/mergekit). To evaluate your merges, see [🧐 LLM AutoEval](https://colab.research.google.com/drive/1Igs3WZuXAIv9X0vwqiE90QlEPys8e8Oa?usp=sharing#scrollTo=elyxjYI_rY5W).
#
# *Special thanks to [@cg123](https://github.com/cg123) for this library and [@mrfakename](https://gist.github.com/fakerybakery) who told me about sharding (see his [Gist](https://gist.github.com/fakerybakery/d30a4d31b4f914757c1381166b9c683b)).*

# %%
MODEL_NAME = "NeuralPipe-7B-slerp"
yaml_config = """
slices:
  - sources:
      - model: OpenPipe/mistral-ft-optimized-1218
        layer_range: [0, 32]
      - model: mlabonne/NeuralHermes-2.5-Mistral-7B
        layer_range: [0, 32]
merge_method: slerp
base_model: OpenPipe/mistral-ft-optimized-1218
parameters:
  t:
    - filter: self_attn
      value: [0, 0.5, 0.3, 0.7, 1]
    - filter: mlp
      value: [1, 0.5, 0.7, 0.3, 0]
    - value: 0.5
dtype: bfloat16
"""

# %%
# @title ## Run merge

# @markdown ### Runtime type
# @markdown Select your runtime (CPU, High RAM, GPU)

runtime = "CPU" # @param ["CPU", "CPU + High-RAM", "GPU"]

# @markdown ### Mergekit arguments
# @markdown Use the `main` branch by default, [`mixtral`](https://github.com/cg123/mergekit/blob/mixtral/moe.md) if you want to create a Mixture of Experts.

branch = "main" # @param ["main", "mixtral"]
trust_remote_code = False # @param {type:"boolean"}

# Install mergekit
if branch == "main":
    # !git clone https://github.com/arcee-ai/mergekit.git
    # !cd mergekit && pip install -qqq -e . --progress-bar off
elif branch == "mixtral":
    # !git clone -b mixtral https://github.com/arcee-ai/mergekit.git
    # !cd mergekit && pip install -qqq -e . --progress-bar off
    # !pip install -qqq -U transformers --progress-bar off

# Save config as yaml file
with open('config.yaml', 'w', encoding="utf-8") as f:
    f.write(yaml_config)

# Base CLI
if branch == "main":
    cli = "mergekit-yaml config.yaml merge --copy-tokenizer"
elif branch == "mixtral":
    cli = "mergekit-moe config.yaml merge --copy-tokenizer"

# Additional arguments
if runtime == "CPU":
    cli += " --allow-crimes --out-shard-size 1B --lazy-unpickle"
elif runtime == "GPU":
    cli += " --cuda --low-cpu-memory"
if trust_remote_code:
    cli += " --trust-remote-code"

print(cli)

# Merge models
# !{cli}
# Out:
# Cloning into 'mergekit'...
# remote: Enumerating objects: 2205, done.
# remote: Counting objects: 100% (1280/1280), done.
# remote: Compressing objects: 100% (487/487), done.
# remote: Total 2205 (delta 1023), reused 894 (delta 792), pack-reused 925
# Receiving objects: 100% (2205/2205), 626.93 KiB | 2.37 MiB/s, done.
# Resolving deltas: 100% (1539/1539), done.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for mergekit (pyproject.toml) ... done
# mergekit-yaml config.yaml merge --copy-tokenizer --cuda --low-cpu-memory --trust-remote-code
# config.json: 100% 3.35k/3.35k [00:00<00:00, 17.7MB/s]
# configuration_phi3.py: 100% 10.4k/10.4k [00:00<00:00, 38.0MB/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-128k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# config.json: 100% 3.92k/3.92k [00:00<00:00, 17.9MB/s]
# Warmup loader cache:   0% 0/2 [00:00<?, ?it/s]
# Fetching 10 files:   0% 0/10 [00:00<?, ?it/s]
#
# model-00002-of-00002.safetensors:   0% 0.00/2.67G [00:00<?, ?B/s]
#
#
# tokenizer.json:   0% 0.00/1.84M [00:00<?, ?B/s]
#
#
#
# generation_config.json: 100% 172/172 [00:00<00:00, 941kB/s]
#
#
#
#
# added_tokens.json: 100% 293/293 [00:00<00:00, 1.41MB/s]
#
# Fetching 10 files:  10% 1/10 [00:00<00:04,  1.83it/s]
#
#
#
# special_tokens_map.json: 100% 568/568 [00:00<00:00, 3.31MB/s]
#
#
#
#
# model.safetensors.index.json: 100% 16.3k/16.3k [00:00<00:00, 55.6MB/s]
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 19.5MB/s]
#
#
#
# model-00001-of-00002.safetensors:   0% 0.00/4.97G [00:00<?, ?B/s]
#
# model-00002-of-00002.safetensors:   1% 21.0M/2.67G [00:00<00:17, 154MB/s]
#
#
#
# tokenizer_config.json: 100% 3.17k/3.17k [00:00<00:00, 12.8MB/s]
#
#
#
#
# tokenizer.model:   0% 0.00/500k [00:00<?, ?B/s]
#
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 13.2MB/s]
#
#
# model-00002-of-00002.safetensors:   2% 52.4M/2.67G [00:00<00:13, 200MB/s]
#
#
# model-00001-of-00002.safetensors:   1% 52.4M/4.97G [00:00<00:23, 207MB/s]
#
# model-00002-of-00002.safetensors:   3% 83.9M/2.67G [00:00<00:11, 217MB/s]
#
#
# model-00001-of-00002.safetensors:   1% 73.4M/4.97G [00:00<00:25, 194MB/s]
#
# model-00002-of-00002.safetensors:   4% 115M/2.67G [00:00<00:13, 194MB/s]
#
#
# model-00001-of-00002.safetensors:   2% 94.4M/4.97G [00:00<00:28, 171MB/s]
#
# model-00002-of-00002.safetensors:   5% 136M/2.67G [00:00<00:14, 176MB/s]
#
#
# model-00001-of-00002.safetensors:   2% 115M/4.97G [00:00<00:30, 158MB/s]
#
# model-00002-of-00002.safetensors:   6% 157M/2.67G [00:00<00:15, 162MB/s]
#
#
# model-00001-of-00002.safetensors:   3% 136M/4.97G [00:00<00:29, 163MB/s]
#
#
# model-00001-of-00002.safetensors:   3% 157M/4.97G [00:00<00:27, 174MB/s]
#
# model-00002-of-00002.safetensors:   7% 178M/2.67G [00:01<00:16, 151MB/s]
#
#
# model-00001-of-00002.safetensors:   4% 178M/4.97G [00:01<00:27, 173MB/s]
#
# model-00002-of-00002.safetensors:   7% 199M/2.67G [00:01<00:15, 156MB/s]
#
#
# model-00001-of-00002.safetensors:   4% 199M/4.97G [00:01<00:27, 176MB/s]
#
# model-00002-of-00002.safetensors:   8% 220M/2.67G [00:01<00:15, 157MB/s]
#
#
# model-00001-of-00002.safetensors:   4% 220M/4.97G [00:01<00:27, 176MB/s]
#
# model-00002-of-00002.safetensors:   9% 241M/2.67G [00:01<00:15, 158MB/s]
#
#
# model-00001-of-00002.safetensors:   5% 241M/4.97G [00:01<00:29, 159MB/s]
#
# model-00002-of-00002.safetensors:  10% 262M/2.67G [00:01<00:17, 141MB/s]
#
#
# model-00001-of-00002.safetensors:   5% 262M/4.97G [00:01<00:39, 120MB/s]
#
# model-00002-of-00002.safetensors:  11% 283M/2.67G [00:01<00:21, 112MB/s]
#
#
# model-00001-of-00002.safetensors:   6% 283M/4.97G [00:05<05:09, 15.2MB/s]
#
# model-00002-of-00002.safetensors:  11% 304M/2.67G [00:06<02:33, 15.4MB/s]
#
# model-00002-of-00002.safetensors:  12% 315M/2.67G [00:06<02:10, 18.0MB/s]
#
#
# model-00001-of-00002.safetensors:   6% 304M/4.97G [00:06<03:49, 20.4MB/s]
#
# model-00002-of-00002.safetensors:  12% 325M/2.67G [00:06<01:51, 21.0MB/s]
#
#
# model-00001-of-00002.safetensors:   6% 315M/4.97G [00:06<03:25, 22.6MB/s]
#
# model-00002-of-00002.safetensors:  13% 336M/2.67G [00:06<01:36, 24.2MB/s]
#
#
# model-00001-of-00002.safetensors:   7% 336M/4.97G [00:06<02:27, 31.3MB/s]
#
# model-00002-of-00002.safetensors:  13% 346M/2.67G [00:06<01:19, 29.1MB/s]
#
#
# model-00001-of-00002.safetensors:   7% 357M/4.97G [00:06<01:50, 41.8MB/s]
#
# model-00002-of-00002.safetensors:  14% 367M/2.67G [00:06<00:52, 43.6MB/s]
#
# model-00002-of-00002.safetensors:  15% 388M/2.67G [00:06<00:40, 55.7MB/s]
#
#
# model-00001-of-00002.safetensors:   8% 377M/4.97G [00:06<01:33, 49.0MB/s]
#
# model-00002-of-00002.safetensors:  15% 409M/2.67G [00:07<00:31, 71.6MB/s]
#
#
# model-00001-of-00002.safetensors:   8% 398M/4.97G [00:07<01:13, 61.9MB/s]
#
# model-00002-of-00002.safetensors:  16% 430M/2.67G [00:07<00:26, 85.0MB/s]
#
#
# model-00001-of-00002.safetensors:   8% 419M/4.97G [00:07<01:04, 70.9MB/s]
#
# model-00002-of-00002.safetensors:  17% 451M/2.67G [00:07<00:22, 100MB/s]
#
#
# model-00001-of-00002.safetensors:   9% 440M/4.97G [00:07<00:53, 84.6MB/s]
#
# model-00002-of-00002.safetensors:  18% 472M/2.67G [00:07<00:19, 115MB/s]
#
#
# model-00001-of-00002.safetensors:   9% 461M/4.97G [00:07<00:45, 99.8MB/s]
#
# model-00002-of-00002.safetensors:  18% 493M/2.67G [00:07<00:17, 126MB/s]
#
#
# model-00001-of-00002.safetensors:  10% 482M/4.97G [00:07<00:38, 117MB/s]
#
# model-00002-of-00002.safetensors:  19% 514M/2.67G [00:07<00:16, 132MB/s]
#
#
# model-00001-of-00002.safetensors:  10% 503M/4.97G [00:07<00:34, 131MB/s]
#
# model-00002-of-00002.safetensors:  20% 535M/2.67G [00:07<00:15, 140MB/s]
#
#
# model-00001-of-00002.safetensors:  11% 524M/4.97G [00:07<00:31, 142MB/s]
#
# model-00002-of-00002.safetensors:  21% 556M/2.67G [00:08<00:13, 151MB/s]
#
#
# model-00001-of-00002.safetensors:  11% 545M/4.97G [00:07<00:30, 143MB/s]
#
# model-00002-of-00002.safetensors:  22% 577M/2.67G [00:08<00:13, 157MB/s]
#
#
# model-00001-of-00002.safetensors:  11% 566M/4.97G [00:08<00:30, 144MB/s]
#
# model-00002-of-00002.safetensors:  22% 598M/2.67G [00:08<00:13, 150MB/s]
#
#
# model-00001-of-00002.safetensors:  12% 587M/4.97G [00:08<00:32, 134MB/s]
#
# model-00002-of-00002.safetensors:  23% 619M/2.67G [00:08<00:14, 141MB/s]
#
#
# model-00001-of-00002.safetensors:  12% 608M/4.97G [00:09<01:52, 38.8MB/s]
#
# model-00002-of-00002.safetensors:  24% 640M/2.67G [00:09<00:50, 39.8MB/s]
#
#
# model-00001-of-00002.safetensors:  13% 629M/4.97G [00:09<01:28, 49.3MB/s]
#
# model-00002-of-00002.safetensors:  25% 661M/2.67G [00:10<00:39, 50.9MB/s]
#
# model-00002-of-00002.safetensors:  26% 682M/2.67G [00:10<00:30, 64.7MB/s]
#
#
# model-00001-of-00002.safetensors:  13% 650M/4.97G [00:10<01:11, 60.9MB/s]
#
# model-00002-of-00002.safetensors:  26% 703M/2.67G [00:10<00:25, 77.8MB/s]
#
#
# model-00001-of-00002.safetensors:  13% 671M/4.97G [00:10<00:59, 71.9MB/s]
#
# model-00002-of-00002.safetensors:  27% 724M/2.67G [00:10<00:21, 90.5MB/s]
#
#
# model-00001-of-00002.safetensors:  14% 692M/4.97G [00:10<00:49, 87.1MB/s]
#
# model-00002-of-00002.safetensors:  28% 744M/2.67G [00:10<00:29, 64.5MB/s]
#
#
# model-00001-of-00002.safetensors:  14% 713M/4.97G [00:10<01:09, 61.4MB/s]
#
# model-00002-of-00002.safetensors:  29% 765M/2.67G [00:11<00:24, 78.6MB/s]
#
#
# model-00001-of-00002.safetensors:  15% 734M/4.97G [00:11<00:58, 72.2MB/s]
#
# model-00002-of-00002.safetensors:  29% 786M/2.67G [00:11<00:22, 83.2MB/s]
#
#
# model-00001-of-00002.safetensors:  15% 755M/4.97G [00:11<00:59, 71.0MB/s]
#
# model-00002-of-00002.safetensors:  30% 807M/2.67G [00:11<00:24, 76.3MB/s]
#
#
# model-00001-of-00002.safetensors:  15% 765M/4.97G [00:11<01:00, 69.9MB/s]
#
#
# model-00001-of-00002.safetensors:  16% 776M/4.97G [00:11<00:57, 72.8MB/s]
#
# model-00002-of-00002.safetensors:  31% 828M/2.67G [00:11<00:21, 87.4MB/s]
#
#
# model-00001-of-00002.safetensors:  16% 797M/4.97G [00:11<00:46, 90.6MB/s]
#
# model-00002-of-00002.safetensors:  32% 849M/2.67G [00:11<00:18, 97.4MB/s]
#
#
# model-00001-of-00002.safetensors:  16% 818M/4.97G [00:12<00:44, 93.1MB/s]
#
# model-00002-of-00002.safetensors:  33% 870M/2.67G [00:12<00:18, 97.7MB/s]
#
# model-00002-of-00002.safetensors:  33% 891M/2.67G [00:13<00:49, 36.0MB/s]
#
#
# model-00001-of-00002.safetensors:  17% 839M/4.97G [00:13<02:05, 32.9MB/s]
#
#
# model-00001-of-00002.safetensors:  17% 860M/4.97G [00:13<01:33, 44.0MB/s]
#
# model-00002-of-00002.safetensors:  34% 912M/2.67G [00:13<00:37, 46.5MB/s]
#
#
# model-00001-of-00002.safetensors:  18% 881M/4.97G [00:13<01:10, 57.8MB/s]
#
# model-00002-of-00002.safetensors:  35% 933M/2.67G [00:13<00:29, 59.4MB/s]
#
#
# model-00001-of-00002.safetensors:  18% 902M/4.97G [00:13<00:55, 73.6MB/s]
#
# model-00002-of-00002.safetensors:  36% 954M/2.67G [00:14<00:23, 72.0MB/s]
#
#
# model-00001-of-00002.safetensors:  19% 923M/4.97G [00:14<00:48, 83.6MB/s]
#
# model-00002-of-00002.safetensors:  37% 975M/2.67G [00:14<00:21, 80.6MB/s]
#
#
# model-00001-of-00002.safetensors:  19% 944M/4.97G [00:14<00:42, 94.6MB/s]
#
# model-00002-of-00002.safetensors:  37% 996M/2.67G [00:15<00:53, 31.1MB/s]
#
#
# model-00001-of-00002.safetensors:  19% 965M/4.97G [00:15<02:03, 32.5MB/s]
#
# model-00002-of-00002.safetensors:  38% 1.02G/2.67G [00:16<00:56, 29.2MB/s]
#
#
# model-00001-of-00002.safetensors:  20% 975M/4.97G [00:16<02:32, 26.2MB/s]
#
# model-00002-of-00002.safetensors:  39% 1.05G/2.67G [00:16<00:36, 44.0MB/s]
#
#
# model-00001-of-00002.safetensors:  20% 1.01G/4.97G [00:16<01:34, 42.0MB/s]
#
# model-00002-of-00002.safetensors:  40% 1.07G/2.67G [00:16<00:29, 54.4MB/s]
#
#
# model-00001-of-00002.safetensors:  21% 1.03G/4.97G [00:16<01:16, 51.5MB/s]
#
# model-00002-of-00002.safetensors:  41% 1.09G/2.67G [00:17<00:23, 67.7MB/s]
#
#
# model-00001-of-00002.safetensors:  21% 1.05G/4.97G [00:17<01:01, 63.9MB/s]
#
# model-00002-of-00002.safetensors:  42% 1.11G/2.67G [00:17<00:19, 81.2MB/s]
#
# model-00002-of-00002.safetensors:  42% 1.13G/2.67G [00:18<00:42, 36.3MB/s]
#
#
# model-00001-of-00002.safetensors:  22% 1.07G/4.97G [00:18<02:01, 32.0MB/s]
#
# model-00002-of-00002.safetensors:  43% 1.15G/2.67G [00:18<00:31, 47.7MB/s]
#
#
# model-00001-of-00002.safetensors:  22% 1.09G/4.97G [00:18<01:31, 42.5MB/s]
#
#
# model-00001-of-00002.safetensors:  22% 1.11G/4.97G [00:18<01:09, 55.7MB/s]
#
# model-00002-of-00002.safetensors:  44% 1.18G/2.67G [00:18<00:21, 68.2MB/s]
#
#
# model-00001-of-00002.safetensors:  23% 1.13G/4.97G [00:18<00:55, 69.0MB/s]
#
# model-00002-of-00002.safetensors:  45% 1.21G/2.67G [00:18<00:18, 80.5MB/s]
#
# model-00002-of-00002.safetensors:  46% 1.23G/2.67G [00:19<00:14, 96.2MB/s]
#
# model-00002-of-00002.safetensors:  47% 1.25G/2.67G [00:19<00:12, 113MB/s]
#
# model-00002-of-00002.safetensors:  48% 1.27G/2.67G [00:19<00:10, 128MB/s]
#
#
# model-00001-of-00002.safetensors:  23% 1.15G/4.97G [00:19<00:58, 65.3MB/s]
#
# model-00002-of-00002.safetensors:  48% 1.29G/2.67G [00:19<00:09, 138MB/s]
#
#
# model-00001-of-00002.safetensors:  24% 1.17G/4.97G [00:19<00:47, 79.6MB/s]
#
# model-00002-of-00002.safetensors:  49% 1.31G/2.67G [00:19<00:09, 141MB/s]
#
#
# model-00001-of-00002.safetensors:  24% 1.20G/4.97G [00:19<00:40, 94.3MB/s]
#
#
# model-00001-of-00002.safetensors:  24% 1.22G/4.97G [00:19<00:35, 107MB/s]
#
#
# model-00001-of-00002.safetensors:  25% 1.25G/4.97G [00:19<00:27, 138MB/s]
#
# model-00002-of-00002.safetensors:  50% 1.33G/2.67G [00:19<00:12, 104MB/s]
#
#
# model-00001-of-00002.safetensors:  26% 1.27G/4.97G [00:19<00:24, 151MB/s]
#
# model-00002-of-00002.safetensors:  51% 1.35G/2.67G [00:20<00:11, 113MB/s]
#
#
# model-00001-of-00002.safetensors:  26% 1.29G/4.97G [00:19<00:23, 154MB/s]
#
# model-00002-of-00002.safetensors:  51% 1.37G/2.67G [00:20<00:10, 123MB/s]
#
#
# model-00001-of-00002.safetensors:  26% 1.31G/4.97G [00:20<00:23, 156MB/s]
#
# model-00002-of-00002.safetensors:  52% 1.39G/2.67G [00:20<00:09, 135MB/s]
#
#
# model-00001-of-00002.safetensors:  27% 1.33G/4.97G [00:20<00:22, 159MB/s]
#
# model-00002-of-00002.safetensors:  53% 1.42G/2.67G [00:20<00:08, 146MB/s]
#
#
# model-00001-of-00002.safetensors:  27% 1.35G/4.97G [00:20<00:23, 152MB/s]
#
# model-00002-of-00002.safetensors:  54% 1.44G/2.67G [00:20<00:08, 145MB/s]
#
#
# model-00001-of-00002.safetensors:  28% 1.37G/4.97G [00:20<00:23, 154MB/s]
#
# model-00002-of-00002.safetensors:  55% 1.46G/2.67G [00:20<00:07, 157MB/s]
#
#
# model-00001-of-00002.safetensors:  28% 1.39G/4.97G [00:20<00:23, 152MB/s]
#
# model-00002-of-00002.safetensors:  55% 1.48G/2.67G [00:20<00:07, 163MB/s]
#
#
# model-00001-of-00002.safetensors:  28% 1.42G/4.97G [00:20<00:23, 149MB/s]
#
# model-00002-of-00002.safetensors:  56% 1.50G/2.67G [00:20<00:07, 148MB/s]
#
#
# model-00001-of-00002.safetensors:  29% 1.44G/4.97G [00:20<00:24, 142MB/s]
#
# model-00002-of-00002.safetensors:  57% 1.52G/2.67G [00:21<00:08, 131MB/s]
#
#
# model-00001-of-00002.safetensors:  29% 1.46G/4.97G [00:21<00:29, 118MB/s]
#
# model-00002-of-00002.safetensors:  58% 1.54G/2.67G [00:21<00:09, 117MB/s]
#
#
# model-00001-of-00002.safetensors:  30% 1.48G/4.97G [00:21<00:33, 106MB/s]
#
# model-00002-of-00002.safetensors:  59% 1.56G/2.67G [00:21<00:10, 103MB/s]
#
#
# model-00001-of-00002.safetensors:  30% 1.50G/4.97G [00:21<00:34, 101MB/s]
#
# model-00002-of-00002.safetensors:  59% 1.58G/2.67G [00:21<00:10, 106MB/s]
#
#
# model-00001-of-00002.safetensors:  31% 1.52G/4.97G [00:21<00:32, 106MB/s]
#
# model-00002-of-00002.safetensors:  60% 1.60G/2.67G [00:21<00:09, 107MB/s]
#
#
# model-00001-of-00002.safetensors:  31% 1.54G/4.97G [00:22<00:32, 105MB/s]
#
# model-00002-of-00002.safetensors:  61% 1.63G/2.67G [00:22<00:09, 107MB/s]
#
#
# model-00001-of-00002.safetensors:  31% 1.56G/4.97G [00:25<03:33, 16.0MB/s]
#
# model-00002-of-00002.safetensors:  62% 1.65G/2.67G [00:26<01:03, 16.0MB/s]
#
# model-00002-of-00002.safetensors:  62% 1.66G/2.67G [00:26<00:55, 18.3MB/s]
#
#
# model-00001-of-00002.safetensors:  32% 1.58G/4.97G [00:26<02:43, 20.7MB/s]
#
# model-00002-of-00002.safetensors:  62% 1.67G/2.67G [00:26<00:47, 21.3MB/s]
#
#
# model-00001-of-00002.safetensors:  32% 1.59G/4.97G [00:26<02:21, 23.9MB/s]
#
#
# model-00001-of-00002.safetensors:  32% 1.60G/4.97G [00:26<02:00, 28.1MB/s]
#
# model-00002-of-00002.safetensors:  63% 1.69G/2.67G [00:26<00:31, 30.7MB/s]
#
#
# model-00001-of-00002.safetensors:  32% 1.61G/4.97G [00:26<01:40, 33.5MB/s]
#
# model-00002-of-00002.safetensors:  64% 1.71G/2.67G [00:26<00:22, 42.7MB/s]
#
# model-00002-of-00002.safetensors:  65% 1.73G/2.67G [00:26<00:17, 53.7MB/s]
#
#
# model-00001-of-00002.safetensors:  33% 1.64G/4.97G [00:26<01:14, 44.7MB/s]
#
#
# model-00001-of-00002.safetensors:  33% 1.65G/4.97G [00:26<01:07, 49.2MB/s]
#
# model-00002-of-00002.safetensors:  66% 1.75G/2.67G [00:27<00:14, 62.6MB/s]
#
#
# model-00001-of-00002.safetensors:  34% 1.67G/4.97G [00:27<00:59, 55.8MB/s]
#
# model-00002-of-00002.safetensors:  66% 1.77G/2.67G [00:27<00:13, 67.8MB/s]
#
#
# model-00001-of-00002.safetensors:  34% 1.69G/4.97G [00:27<00:48, 67.8MB/s]
#
# model-00002-of-00002.safetensors:  67% 1.79G/2.67G [00:27<00:11, 77.6MB/s]
#
#
# model-00001-of-00002.safetensors:  34% 1.70G/4.97G [00:31<04:29, 12.1MB/s]
#
# model-00002-of-00002.safetensors:  68% 1.80G/2.67G [00:31<01:03, 13.6MB/s]
#
# model-00002-of-00002.safetensors:  68% 1.82G/2.67G [00:31<00:42, 19.8MB/s]
#
#
# model-00001-of-00002.safetensors:  35% 1.72G/4.97G [00:31<02:58, 18.3MB/s]
#
#
# model-00001-of-00002.safetensors:  35% 1.73G/4.97G [00:31<02:27, 22.0MB/s]
#
# model-00002-of-00002.safetensors:  69% 1.85G/2.67G [00:31<00:29, 27.6MB/s]
#
# model-00002-of-00002.safetensors:  70% 1.87G/2.67G [00:31<00:21, 38.0MB/s]
#
#
# model-00001-of-00002.safetensors:  35% 1.74G/4.97G [00:31<02:04, 25.9MB/s]
#
#
# model-00001-of-00002.safetensors:  35% 1.76G/4.97G [00:31<01:24, 38.2MB/s]
#
# model-00002-of-00002.safetensors:  71% 1.89G/2.67G [00:31<00:16, 48.0MB/s]
#
#
# model-00001-of-00002.safetensors:  36% 1.78G/4.97G [00:31<01:00, 52.4MB/s]
#
# model-00002-of-00002.safetensors:  71% 1.91G/2.67G [00:32<00:13, 55.6MB/s]
#
#
# model-00001-of-00002.safetensors:  36% 1.80G/4.97G [00:32<00:52, 60.6MB/s]
#
# model-00002-of-00002.safetensors:  72% 1.93G/2.67G [00:32<00:11, 66.8MB/s]
#
#
# model-00001-of-00002.safetensors:  37% 1.82G/4.97G [00:32<00:42, 74.6MB/s]
#
# model-00002-of-00002.safetensors:  73% 1.95G/2.67G [00:32<00:08, 82.3MB/s]
#
#
# model-00001-of-00002.safetensors:  37% 1.85G/4.97G [00:32<00:34, 90.1MB/s]
#
# model-00002-of-00002.safetensors:  74% 1.97G/2.67G [00:32<00:07, 94.7MB/s]
#
#
# model-00001-of-00002.safetensors:  38% 1.87G/4.97G [00:32<00:29, 104MB/s]
#
# model-00002-of-00002.safetensors:  75% 1.99G/2.67G [00:32<00:06, 108MB/s]
#
#
# model-00001-of-00002.safetensors:  38% 1.89G/4.97G [00:32<00:27, 114MB/s]
#
# model-00002-of-00002.safetensors:  75% 2.01G/2.67G [00:32<00:05, 119MB/s]
#
#
# model-00001-of-00002.safetensors:  38% 1.91G/4.97G [00:32<00:24, 127MB/s]
#
# model-00002-of-00002.safetensors:  76% 2.03G/2.67G [00:32<00:04, 128MB/s]
#
#
# model-00001-of-00002.safetensors:  39% 1.93G/4.97G [00:32<00:22, 138MB/s]
#
# model-00002-of-00002.safetensors:  77% 2.06G/2.67G [00:33<00:04, 131MB/s]
#
#
# model-00001-of-00002.safetensors:  39% 1.95G/4.97G [00:32<00:20, 144MB/s]
#
# model-00002-of-00002.safetensors:  78% 2.08G/2.67G [00:33<00:04, 134MB/s]
#
#
# model-00001-of-00002.safetensors:  40% 1.97G/4.97G [00:33<00:20, 149MB/s]
#
# model-00002-of-00002.safetensors:  79% 2.10G/2.67G [00:33<00:03, 143MB/s]
#
#
# model-00001-of-00002.safetensors:  40% 1.99G/4.97G [00:33<00:19, 150MB/s]
#
# model-00002-of-00002.safetensors:  79% 2.12G/2.67G [00:33<00:04, 133MB/s]
#
#
# model-00001-of-00002.safetensors:  40% 2.01G/4.97G [00:33<00:20, 145MB/s]
#
# model-00002-of-00002.safetensors:  80% 2.14G/2.67G [00:33<00:03, 135MB/s]
#
#
# model-00001-of-00002.safetensors:  41% 2.03G/4.97G [00:33<00:21, 139MB/s]
#
# model-00002-of-00002.safetensors:  81% 2.16G/2.67G [00:33<00:03, 129MB/s]
#
#
# model-00001-of-00002.safetensors:  41% 2.06G/4.97G [00:33<00:21, 137MB/s]
#
# model-00002-of-00002.safetensors:  82% 2.18G/2.67G [00:33<00:03, 130MB/s]
#
#
# model-00001-of-00002.safetensors:  42% 2.08G/4.97G [00:33<00:22, 131MB/s]
#
# model-00002-of-00002.safetensors:  82% 2.20G/2.67G [00:34<00:03, 128MB/s]
#
#
# model-00001-of-00002.safetensors:  42% 2.10G/4.97G [00:34<00:22, 129MB/s]
#
# model-00002-of-00002.safetensors:  83% 2.22G/2.67G [00:34<00:03, 127MB/s]
#
#
# model-00001-of-00002.safetensors:  43% 2.12G/4.97G [00:34<00:22, 128MB/s]
#
# model-00002-of-00002.safetensors:  84% 2.24G/2.67G [00:34<00:03, 126MB/s]
#
#
# model-00001-of-00002.safetensors:  43% 2.14G/4.97G [00:34<00:22, 128MB/s]
#
# model-00002-of-00002.safetensors:  85% 2.26G/2.67G [00:34<00:03, 128MB/s]
#
#
# model-00001-of-00002.safetensors:  43% 2.16G/4.97G [00:34<00:21, 129MB/s]
#
# model-00002-of-00002.safetensors:  86% 2.29G/2.67G [00:34<00:03, 127MB/s]
#
#
# model-00001-of-00002.safetensors:  44% 2.18G/4.97G [00:34<00:22, 127MB/s]
#
# model-00002-of-00002.safetensors:  86% 2.31G/2.67G [00:34<00:02, 127MB/s]
#
#
# model-00001-of-00002.safetensors:  44% 2.20G/4.97G [00:34<00:21, 128MB/s]
#
# model-00002-of-00002.safetensors:  87% 2.33G/2.67G [00:35<00:02, 126MB/s]
#
#
# model-00001-of-00002.safetensors:  45% 2.22G/4.97G [00:35<00:21, 126MB/s]
#
# model-00002-of-00002.safetensors:  88% 2.35G/2.67G [00:35<00:02, 125MB/s]
#
#
# model-00001-of-00002.safetensors:  45% 2.24G/4.97G [00:35<00:21, 127MB/s]
#
# model-00002-of-00002.safetensors:  89% 2.37G/2.67G [00:35<00:02, 125MB/s]
#
#
# model-00001-of-00002.safetensors:  46% 2.26G/4.97G [00:35<00:21, 125MB/s]
#
# model-00002-of-00002.safetensors:  90% 2.39G/2.67G [00:35<00:02, 125MB/s]
#
#
# model-00001-of-00002.safetensors:  46% 2.29G/4.97G [00:35<00:21, 123MB/s]
#
#
# model-00001-of-00002.safetensors:  46% 2.31G/4.97G [00:36<01:07, 39.6MB/s]
#
# model-00002-of-00002.safetensors:  90% 2.41G/2.67G [00:37<00:06, 38.5MB/s]
#
#
# model-00001-of-00002.safetensors:  47% 2.32G/4.97G [00:37<00:59, 44.4MB/s]
#
# model-00002-of-00002.safetensors:  91% 2.42G/2.67G [00:37<00:05, 43.0MB/s]
#
#
# model-00001-of-00002.safetensors:  47% 2.34G/4.97G [00:37<00:44, 59.6MB/s]
#
# model-00002-of-00002.safetensors:  92% 2.44G/2.67G [00:37<00:03, 56.7MB/s]
#
#
# model-00001-of-00002.safetensors:  47% 2.36G/4.97G [00:37<00:33, 77.0MB/s]
#
# model-00002-of-00002.safetensors:  92% 2.46G/2.67G [00:37<00:02, 71.2MB/s]
#
#
# model-00001-of-00002.safetensors:  48% 2.38G/4.97G [00:37<00:27, 94.9MB/s]
#
# model-00002-of-00002.safetensors:  93% 2.49G/2.67G [00:37<00:02, 83.2MB/s]
#
#
# model-00001-of-00002.safetensors:  48% 2.40G/4.97G [00:37<00:26, 97.4MB/s]
#
# model-00002-of-00002.safetensors:  94% 2.51G/2.67G [00:37<00:01, 90.1MB/s]
#
#
# model-00001-of-00002.safetensors:  49% 2.42G/4.97G [00:37<00:22, 114MB/s]
#
# model-00002-of-00002.safetensors:  95% 2.53G/2.67G [00:37<00:01, 103MB/s]
#
#
# model-00001-of-00002.safetensors:  49% 2.44G/4.97G [00:37<00:20, 121MB/s]
#
# model-00002-of-00002.safetensors:  95% 2.55G/2.67G [00:38<00:01, 116MB/s]
#
#
# model-00001-of-00002.safetensors:  50% 2.46G/4.97G [00:37<00:19, 128MB/s]
#
# model-00002-of-00002.safetensors:  96% 2.57G/2.67G [00:38<00:00, 126MB/s]
#
#
# model-00001-of-00002.safetensors:  50% 2.49G/4.97G [00:38<00:17, 142MB/s]
#
# model-00002-of-00002.safetensors:  97% 2.59G/2.67G [00:38<00:00, 138MB/s]
#
#
# model-00001-of-00002.safetensors:  50% 2.51G/4.97G [00:38<00:17, 141MB/s]
#
# model-00002-of-00002.safetensors:  98% 2.61G/2.67G [00:38<00:00, 134MB/s]
#
#
# model-00001-of-00002.safetensors:  51% 2.53G/4.97G [00:38<00:18, 136MB/s]
#
# model-00002-of-00002.safetensors:  99% 2.63G/2.67G [00:38<00:00, 131MB/s]
#
#
# model-00001-of-00002.safetensors:  51% 2.55G/4.97G [00:38<00:18, 133MB/s]
#
# model-00002-of-00002.safetensors:  99% 2.65G/2.67G [00:38<00:00, 127MB/s]
#
#
# model-00001-of-00002.safetensors:  52% 2.57G/4.97G [00:38<00:18, 132MB/s]
#
# model-00002-of-00002.safetensors: 100% 2.67G/2.67G [00:39<00:00, 118MB/s]
#
#
# model-00002-of-00002.safetensors: 100% 2.67G/2.67G [00:39<00:00, 68.4MB/s]
#
#
#
# model-00001-of-00002.safetensors:  53% 2.61G/4.97G [00:39<00:17, 136MB/s]
#
#
# model-00001-of-00002.safetensors:  53% 2.63G/4.97G [00:39<00:15, 146MB/s]
#
#
# model-00001-of-00002.safetensors:  53% 2.65G/4.97G [00:39<00:14, 157MB/s]
#
#
# model-00001-of-00002.safetensors:  54% 2.67G/4.97G [00:39<00:13, 166MB/s]
#
#
# model-00001-of-00002.safetensors:  54% 2.69G/4.97G [00:39<00:13, 173MB/s]
#
#
# model-00001-of-00002.safetensors:  55% 2.72G/4.97G [00:39<00:12, 179MB/s]
#
#
# model-00001-of-00002.safetensors:  55% 2.74G/4.97G [00:39<00:12, 182MB/s]
#
#
# model-00001-of-00002.safetensors:  56% 2.77G/4.97G [00:39<00:11, 194MB/s]
#
#
# model-00001-of-00002.safetensors:  56% 2.79G/4.97G [00:39<00:11, 198MB/s]
#
#
# model-00001-of-00002.safetensors:  57% 2.81G/4.97G [00:40<00:11, 195MB/s]
#
#
# model-00001-of-00002.safetensors:  57% 2.84G/4.97G [00:40<00:10, 208MB/s]
#
#
# model-00001-of-00002.safetensors:  58% 2.86G/4.97G [00:40<00:10, 205MB/s]
#
#
# model-00001-of-00002.safetensors:  58% 2.88G/4.97G [00:40<00:10, 196MB/s]
#
#
# model-00001-of-00002.safetensors:  58% 2.90G/4.97G [00:40<00:10, 195MB/s]
#
#
# model-00001-of-00002.safetensors:  59% 2.94G/4.97G [00:40<00:09, 209MB/s]
#
#
# model-00001-of-00002.safetensors:  60% 2.97G/4.97G [00:40<00:09, 222MB/s]
#
#
# model-00001-of-00002.safetensors:  60% 3.00G/4.97G [00:40<00:08, 232MB/s]
#
#
# model-00001-of-00002.safetensors:  61% 3.03G/4.97G [00:41<00:09, 200MB/s]
#
#
# model-00001-of-00002.safetensors:  61% 3.05G/4.97G [00:41<00:09, 201MB/s]
#
#
# model-00001-of-00002.safetensors:  62% 3.08G/4.97G [00:41<00:08, 212MB/s]
#
#
# model-00001-of-00002.safetensors:  63% 3.11G/4.97G [00:41<00:17, 104MB/s]
#
#
# model-00001-of-00002.safetensors:  63% 3.15G/4.97G [00:42<00:14, 129MB/s]
#
#
# model-00001-of-00002.safetensors:  64% 3.17G/4.97G [00:42<00:12, 142MB/s]
#
#
# model-00001-of-00002.safetensors:  64% 3.19G/4.97G [00:42<00:12, 140MB/s]
#
#
# model-00001-of-00002.safetensors:  65% 3.21G/4.97G [00:42<00:12, 142MB/s]
#
#
# model-00001-of-00002.safetensors:  65% 3.23G/4.97G [00:42<00:11, 154MB/s]
#
#
# model-00001-of-00002.safetensors:  66% 3.26G/4.97G [00:42<00:09, 177MB/s]
#
#
# model-00001-of-00002.safetensors:  66% 3.28G/4.97G [00:42<00:09, 180MB/s]
#
#
# model-00001-of-00002.safetensors:  67% 3.31G/4.97G [00:43<00:09, 175MB/s]
#
#
# model-00001-of-00002.safetensors:  67% 3.34G/4.97G [00:43<00:08, 191MB/s]
#
#
# model-00001-of-00002.safetensors:  68% 3.38G/4.97G [00:43<00:07, 204MB/s]
#
#
# model-00001-of-00002.safetensors:  69% 3.41G/4.97G [00:43<00:06, 224MB/s]
#
#
# model-00001-of-00002.safetensors:  69% 3.44G/4.97G [00:43<00:06, 237MB/s]
#
#
# model-00001-of-00002.safetensors:  70% 3.47G/4.97G [00:43<00:06, 235MB/s]
#
#
# model-00001-of-00002.safetensors:  70% 3.50G/4.97G [00:43<00:06, 235MB/s]
#
#
# model-00001-of-00002.safetensors:  71% 3.53G/4.97G [00:45<00:31, 45.6MB/s]
#
#
# model-00001-of-00002.safetensors:  72% 3.57G/4.97G [00:45<00:23, 60.5MB/s]
#
#
# model-00001-of-00002.safetensors:  72% 3.59G/4.97G [00:46<00:20, 69.3MB/s]
#
#
# model-00001-of-00002.safetensors:  73% 3.61G/4.97G [00:46<00:16, 80.8MB/s]
#
#
# model-00001-of-00002.safetensors:  73% 3.63G/4.97G [00:46<00:14, 94.3MB/s]
#
#
# model-00001-of-00002.safetensors:  73% 3.65G/4.97G [00:46<00:12, 109MB/s]
#
#
# model-00001-of-00002.safetensors:  74% 3.67G/4.97G [00:46<00:10, 126MB/s]
#
#
# model-00001-of-00002.safetensors:  74% 3.70G/4.97G [00:46<00:08, 143MB/s]
#
#
# model-00001-of-00002.safetensors:  75% 3.72G/4.97G [00:46<00:08, 148MB/s]
#
#
# model-00001-of-00002.safetensors:  75% 3.75G/4.97G [00:46<00:07, 171MB/s]
#
#
# model-00001-of-00002.safetensors:  76% 3.79G/4.97G [00:47<00:06, 191MB/s]
#
#
# model-00001-of-00002.safetensors:  77% 3.82G/4.97G [00:47<00:05, 213MB/s]
#
#
# model-00001-of-00002.safetensors:  77% 3.85G/4.97G [00:47<00:04, 227MB/s]
#
#
# model-00001-of-00002.safetensors:  78% 3.88G/4.97G [00:47<00:04, 238MB/s]
#
#
# model-00001-of-00002.safetensors:  79% 3.91G/4.97G [00:47<00:04, 247MB/s]
#
#
# model-00001-of-00002.safetensors:  79% 3.94G/4.97G [00:47<00:04, 229MB/s]
#
#
# model-00001-of-00002.safetensors:  80% 3.97G/4.97G [00:47<00:04, 219MB/s]
#
#
# model-00001-of-00002.safetensors:  81% 4.01G/4.97G [00:47<00:04, 219MB/s]
#
#
# model-00001-of-00002.safetensors:  81% 4.04G/4.97G [00:52<00:39, 23.5MB/s]
#
#
# model-00001-of-00002.safetensors:  82% 4.07G/4.97G [00:52<00:27, 32.3MB/s]
#
#
# model-00001-of-00002.safetensors:  82% 4.10G/4.97G [00:52<00:20, 43.0MB/s]
#
#
# model-00001-of-00002.safetensors:  83% 4.12G/4.97G [00:52<00:16, 51.3MB/s]
#
#
# model-00001-of-00002.safetensors:  83% 4.14G/4.97G [00:52<00:13, 61.5MB/s]
#
#
# model-00001-of-00002.safetensors:  84% 4.16G/4.97G [00:52<00:10, 73.9MB/s]
#
#
# model-00001-of-00002.safetensors:  84% 4.19G/4.97G [00:52<00:08, 95.7MB/s]
#
#
# model-00001-of-00002.safetensors:  85% 4.22G/4.97G [00:53<00:06, 108MB/s]
#
#
# model-00001-of-00002.safetensors:  85% 4.24G/4.97G [00:53<00:05, 124MB/s]
#
#
# model-00001-of-00002.safetensors:  86% 4.27G/4.97G [00:53<00:04, 152MB/s]
#
#
# model-00001-of-00002.safetensors:  86% 4.30G/4.97G [00:53<00:03, 172MB/s]
#
#
# model-00001-of-00002.safetensors:  87% 4.33G/4.97G [00:53<00:03, 185MB/s]
#
#
# model-00001-of-00002.safetensors:  88% 4.36G/4.97G [00:53<00:03, 203MB/s]
#
#
# model-00001-of-00002.safetensors:  88% 4.39G/4.97G [00:53<00:02, 214MB/s]
#
#
# model-00001-of-00002.safetensors:  89% 4.42G/4.97G [00:53<00:02, 228MB/s]
#
#
# model-00001-of-00002.safetensors:  90% 4.46G/4.97G [00:54<00:02, 233MB/s]
#
#
# model-00001-of-00002.safetensors:  90% 4.49G/4.97G [00:54<00:02, 237MB/s]
#
#
# model-00001-of-00002.safetensors:  91% 4.52G/4.97G [00:54<00:01, 240MB/s]
#
#
# model-00001-of-00002.safetensors:  92% 4.55G/4.97G [00:54<00:01, 242MB/s]
#
#
# model-00001-of-00002.safetensors:  92% 4.58G/4.97G [00:54<00:01, 247MB/s]
#
#
# model-00001-of-00002.safetensors:  93% 4.61G/4.97G [00:54<00:01, 248MB/s]
#
#
# model-00001-of-00002.safetensors:  93% 4.65G/4.97G [00:54<00:01, 250MB/s]
#
#
# model-00001-of-00002.safetensors:  94% 4.68G/4.97G [00:54<00:01, 243MB/s]
#
#
# model-00001-of-00002.safetensors:  95% 4.71G/4.97G [00:55<00:01, 247MB/s]
#
#
# model-00001-of-00002.safetensors:  95% 4.74G/4.97G [00:55<00:00, 248MB/s]
#
#
# model-00001-of-00002.safetensors:  96% 4.77G/4.97G [00:55<00:00, 246MB/s]
#
#
# model-00001-of-00002.safetensors:  97% 4.80G/4.97G [00:55<00:00, 239MB/s]
#
#
# model-00001-of-00002.safetensors:  97% 4.83G/4.97G [00:55<00:00, 245MB/s]
#
#
# model-00001-of-00002.safetensors:  98% 4.87G/4.97G [00:55<00:00, 251MB/s]
#
#
# model-00001-of-00002.safetensors:  98% 4.90G/4.97G [00:55<00:00, 253MB/s]
#
#
# model-00001-of-00002.safetensors:  99% 4.93G/4.97G [00:55<00:00, 258MB/s]
#
#
# model-00001-of-00002.safetensors: 100% 4.97G/4.97G [00:56<00:00, 88.6MB/s]
#
# Fetching 10 files: 100% 10/10 [00:56<00:00,  5.67s/it]
# Warmup loader cache:  50% 1/2 [00:57<00:57, 57.02s/it]
# Fetching 8 files:   0% 0/8 [00:00<?, ?it/s]
#
# added_tokens.json: 100% 293/293 [00:00<00:00, 1.40MB/s]
#
# Fetching 8 files:  12% 1/8 [00:00<00:01,  5.60it/s]
#
# special_tokens_map.json: 100% 569/569 [00:00<00:00, 3.50MB/s]
#
#
# tokenizer_config.json: 100% 3.17k/3.17k [00:00<00:00, 17.5MB/s]
#
#
# generation_config.json: 100% 172/172 [00:00<00:00, 1.14MB/s]
#
#
# tokenizer.json:   0% 0.00/1.84M [00:00<?, ?B/s]
#
#
# model.safetensors:   0% 0.00/4.02G [00:00<?, ?B/s]
#
#
#
# tokenizer.model: 100% 500k/500k [00:00<00:00, 6.45MB/s]
#
#
# tokenizer.json: 100% 1.84M/1.84M [00:00<00:00, 5.65MB/s]
#
#
#
# model.safetensors:   0% 10.5M/4.02G [00:00<02:16, 29.4MB/s]
#
#
# model.safetensors:   1% 21.0M/4.02G [00:00<01:51, 36.0MB/s]
#
#
# model.safetensors:   1% 31.5M/4.02G [00:00<01:23, 47.7MB/s]
#
#
# model.safetensors:   1% 41.9M/4.02G [00:00<01:07, 59.1MB/s]
#
#
# model.safetensors:   1% 52.4M/4.02G [00:01<01:13, 54.3MB/s]
#
#
# model.safetensors:   2% 62.9M/4.02G [00:01<01:13, 53.9MB/s]
#
#
# model.safetensors:   2% 73.4M/4.02G [00:01<01:09, 57.1MB/s]
#
#
# model.safetensors:   2% 83.9M/4.02G [00:01<01:04, 61.1MB/s]
#
#
# model.safetensors:   2% 94.4M/4.02G [00:01<01:09, 56.6MB/s]
#
#
# model.safetensors:   3% 105M/4.02G [00:01<01:10, 55.2MB/s]
#
#
# model.safetensors:   3% 115M/4.02G [00:02<01:40, 38.7MB/s]
#
#
# model.safetensors:   3% 126M/4.02G [00:02<01:23, 46.6MB/s]
#
#
# model.safetensors:   3% 136M/4.02G [00:02<01:25, 45.2MB/s]
#
#
# model.safetensors:   4% 147M/4.02G [00:02<01:13, 53.0MB/s]
#
#
# model.safetensors:   4% 157M/4.02G [00:03<01:05, 59.0MB/s]
#
#
# model.safetensors:   4% 168M/4.02G [00:03<01:30, 42.6MB/s]
#
#
# model.safetensors:   4% 178M/4.02G [00:03<01:15, 50.8MB/s]
#
#
# model.safetensors:   5% 189M/4.02G [00:03<01:06, 57.3MB/s]
#
#
# model.safetensors:   5% 199M/4.02G [00:03<01:06, 57.5MB/s]
#
#
# model.safetensors:   5% 210M/4.02G [00:04<01:03, 59.7MB/s]
#
#
# model.safetensors:   5% 220M/4.02G [00:04<01:08, 55.2MB/s]
#
#
# model.safetensors:   6% 231M/4.02G [00:04<01:35, 39.5MB/s]
#
#
# model.safetensors:   6% 241M/4.02G [00:05<01:45, 35.7MB/s]
#
#
# model.safetensors:   6% 252M/4.02G [00:05<01:34, 39.9MB/s]
#
#
# model.safetensors:   7% 262M/4.02G [00:05<01:31, 41.3MB/s]
#
#
# model.safetensors:   7% 273M/4.02G [00:05<01:51, 33.5MB/s]
#
#
# model.safetensors:   7% 283M/4.02G [00:06<01:30, 41.3MB/s]
#
#
# model.safetensors:   7% 294M/4.02G [00:06<01:25, 43.4MB/s]
#
#
# model.safetensors:   8% 304M/4.02G [00:06<01:42, 36.2MB/s]
#
#
# model.safetensors:   8% 315M/4.02G [00:06<01:24, 43.8MB/s]
#
#
# model.safetensors:   8% 325M/4.02G [00:06<01:10, 52.2MB/s]
#
#
# model.safetensors:   8% 336M/4.02G [00:07<01:01, 59.6MB/s]
#
#
# model.safetensors:   9% 346M/4.02G [00:07<00:58, 63.1MB/s]
#
#
# model.safetensors:   9% 357M/4.02G [00:07<01:32, 39.5MB/s]
#
#
# model.safetensors:   9% 367M/4.02G [00:07<01:17, 47.3MB/s]
#
#
# model.safetensors:   9% 377M/4.02G [00:07<01:11, 50.8MB/s]
#
#
# model.safetensors:  10% 388M/4.02G [00:08<01:12, 50.5MB/s]
#
#
# model.safetensors:  10% 398M/4.02G [00:08<01:29, 40.5MB/s]
#
#
# model.safetensors:  10% 409M/4.02G [00:08<01:27, 41.5MB/s]
#
#
# model.safetensors:  10% 419M/4.02G [00:09<01:54, 31.4MB/s]
#
#
# model.safetensors:  11% 430M/4.02G [00:09<01:37, 36.7MB/s]
#
#
# model.safetensors:  11% 440M/4.02G [00:10<02:01, 29.4MB/s]
#
#
# model.safetensors:  11% 451M/4.02G [00:10<01:40, 35.7MB/s]
#
#
# model.safetensors:  11% 461M/4.02G [00:10<01:21, 43.5MB/s]
#
#
# model.safetensors:  12% 472M/4.02G [00:10<01:17, 45.6MB/s]
#
#
# model.safetensors:  12% 482M/4.02G [00:10<01:24, 41.8MB/s]
#
#
# model.safetensors:  12% 493M/4.02G [00:10<01:10, 49.9MB/s]
#
#
# model.safetensors:  13% 503M/4.02G [00:11<01:15, 46.7MB/s]
#
#
# model.safetensors:  13% 514M/4.02G [00:11<01:10, 50.0MB/s]
#
#
# model.safetensors:  13% 524M/4.02G [00:11<01:02, 56.4MB/s]
#
#
# model.safetensors:  13% 535M/4.02G [00:11<00:55, 62.4MB/s]
#
#
# model.safetensors:  14% 545M/4.02G [00:11<00:50, 69.3MB/s]
#
#
# model.safetensors:  14% 556M/4.02G [00:11<00:53, 65.0MB/s]
#
#
# model.safetensors:  14% 566M/4.02G [00:12<00:52, 66.0MB/s]
#
#
# model.safetensors:  14% 577M/4.02G [00:12<01:09, 49.4MB/s]
#
#
# model.safetensors:  15% 587M/4.02G [00:12<01:07, 50.6MB/s]
#
#
# model.safetensors:  15% 598M/4.02G [00:13<01:41, 33.7MB/s]
#
#
# model.safetensors:  15% 608M/4.02G [00:13<01:39, 34.2MB/s]
#
#
# model.safetensors:  15% 619M/4.02G [00:13<01:20, 42.1MB/s]
#
#
# model.safetensors:  16% 629M/4.02G [00:13<01:07, 50.1MB/s]
#
#
# model.safetensors:  16% 640M/4.02G [00:13<00:58, 57.5MB/s]
#
#
# model.safetensors:  16% 650M/4.02G [00:13<00:52, 64.7MB/s]
#
#
# model.safetensors:  16% 661M/4.02G [00:13<00:47, 71.4MB/s]
#
#
# model.safetensors:  17% 671M/4.02G [00:14<00:43, 76.4MB/s]
#
#
# model.safetensors:  17% 682M/4.02G [00:14<00:51, 64.6MB/s]
#
#
# model.safetensors:  17% 692M/4.02G [00:14<01:29, 37.2MB/s]
#
#
# model.safetensors:  17% 703M/4.02G [00:15<01:16, 43.4MB/s]
#
#
# model.safetensors:  18% 713M/4.02G [00:15<01:05, 50.8MB/s]
#
#
# model.safetensors:  18% 724M/4.02G [00:15<01:01, 53.5MB/s]
#
#
# model.safetensors:  18% 734M/4.02G [00:15<00:53, 61.1MB/s]
#
#
# model.safetensors:  19% 744M/4.02G [00:15<00:48, 67.9MB/s]
#
#
# model.safetensors:  19% 755M/4.02G [00:15<00:54, 59.6MB/s]
#
#
# model.safetensors:  19% 765M/4.02G [00:15<00:48, 66.5MB/s]
#
#
# model.safetensors:  19% 776M/4.02G [00:16<00:45, 70.8MB/s]
#
#
# model.safetensors:  20% 786M/4.02G [00:16<00:42, 76.5MB/s]
#
#
# model.safetensors:  20% 797M/4.02G [00:16<00:59, 54.6MB/s]
#
#
# model.safetensors:  20% 807M/4.02G [00:16<00:52, 61.2MB/s]
#
#
# model.safetensors:  20% 818M/4.02G [00:17<01:20, 39.7MB/s]
#
#
# model.safetensors:  21% 828M/4.02G [00:17<01:11, 44.6MB/s]
#
#
# model.safetensors:  21% 839M/4.02G [00:17<01:33, 34.1MB/s]
#
#
# model.safetensors:  21% 849M/4.02G [00:17<01:28, 36.0MB/s]
#
#
# model.safetensors:  21% 860M/4.02G [00:18<01:21, 38.6MB/s]
#
#
# model.safetensors:  22% 870M/4.02G [00:18<01:31, 34.6MB/s]
#
#
# model.safetensors:  22% 881M/4.02G [00:18<01:13, 42.5MB/s]
#
#
# model.safetensors:  22% 891M/4.02G [00:18<01:02, 50.4MB/s]
#
#
# model.safetensors:  22% 902M/4.02G [00:18<00:59, 52.7MB/s]
#
#
# model.safetensors:  23% 912M/4.02G [00:19<01:04, 48.4MB/s]
#
#
# model.safetensors:  23% 923M/4.02G [00:19<00:59, 52.0MB/s]
#
#
# model.safetensors:  23% 933M/4.02G [00:19<01:20, 38.1MB/s]
#
#
# model.safetensors:  23% 944M/4.02G [00:19<01:06, 46.2MB/s]
#
#
# model.safetensors:  24% 954M/4.02G [00:20<00:58, 52.3MB/s]
#
#
# model.safetensors:  24% 965M/4.02G [00:20<00:56, 54.5MB/s]
#
#
# model.safetensors:  24% 975M/4.02G [00:20<00:49, 61.4MB/s]
#
#
# model.safetensors:  25% 986M/4.02G [00:20<00:44, 68.7MB/s]
#
#
# model.safetensors:  25% 996M/4.02G [00:20<00:49, 60.7MB/s]
#
#
# model.safetensors:  25% 1.01G/4.02G [00:20<00:44, 67.4MB/s]
#
#
# model.safetensors:  25% 1.02G/4.02G [00:20<00:41, 72.6MB/s]
#
#
# model.safetensors:  26% 1.03G/4.02G [00:21<00:38, 77.9MB/s]
#
#
# model.safetensors:  26% 1.04G/4.02G [00:21<00:40, 73.3MB/s]
#
#
# model.safetensors:  26% 1.05G/4.02G [00:21<00:38, 77.9MB/s]
#
#
# model.safetensors:  26% 1.06G/4.02G [00:21<00:36, 81.5MB/s]
#
#
# model.safetensors:  27% 1.07G/4.02G [00:21<00:35, 84.0MB/s]
#
#
# model.safetensors:  27% 1.08G/4.02G [00:21<00:34, 86.0MB/s]
#
#
# model.safetensors:  27% 1.09G/4.02G [00:22<00:59, 49.5MB/s]
#
#
# model.safetensors:  27% 1.10G/4.02G [00:22<00:50, 57.3MB/s]
#
#
# model.safetensors:  28% 1.11G/4.02G [00:22<00:56, 51.4MB/s]
#
#
# model.safetensors:  28% 1.12G/4.02G [00:22<01:00, 47.9MB/s]
#
#
# model.safetensors:  28% 1.13G/4.02G [00:22<00:56, 51.5MB/s]
#
#
# model.safetensors:  28% 1.14G/4.02G [00:23<00:51, 55.8MB/s]
#
#
# model.safetensors:  29% 1.15G/4.02G [00:23<00:47, 60.1MB/s]
#
#
# model.safetensors:  29% 1.16G/4.02G [00:23<00:42, 66.8MB/s]
#
#
# model.safetensors:  29% 1.17G/4.02G [00:23<00:46, 60.9MB/s]
#
#
# model.safetensors:  29% 1.18G/4.02G [00:23<00:49, 57.6MB/s]
#
#
# model.safetensors:  30% 1.20G/4.02G [00:23<00:44, 64.2MB/s]
#
#
# model.safetensors:  30% 1.21G/4.02G [00:24<00:47, 59.3MB/s]
#
#
# model.safetensors:  30% 1.22G/4.02G [00:24<01:10, 40.0MB/s]
#
#
# model.safetensors:  31% 1.23G/4.02G [00:24<01:07, 41.3MB/s]
#
#
# model.safetensors:  31% 1.24G/4.02G [00:24<01:07, 41.5MB/s]
#
#
# model.safetensors:  31% 1.25G/4.02G [00:25<00:55, 49.6MB/s]
#
#
# model.safetensors:  31% 1.26G/4.02G [00:25<00:49, 55.4MB/s]
#
#
# model.safetensors:  32% 1.27G/4.02G [00:25<01:01, 45.0MB/s]
#
#
# model.safetensors:  32% 1.28G/4.02G [00:25<01:01, 44.3MB/s]
#
#
# model.safetensors:  32% 1.29G/4.02G [00:26<01:11, 38.5MB/s]
#
#
# model.safetensors:  32% 1.30G/4.02G [00:26<01:12, 37.8MB/s]
#
#
# model.safetensors:  33% 1.31G/4.02G [00:26<00:59, 45.4MB/s]
#
#
# model.safetensors:  33% 1.32G/4.02G [00:26<00:57, 46.9MB/s]
#
#
# model.safetensors:  33% 1.33G/4.02G [00:27<00:57, 47.1MB/s]
#
#
# model.safetensors:  33% 1.34G/4.02G [00:27<00:49, 54.7MB/s]
#
#
# model.safetensors:  34% 1.35G/4.02G [00:27<00:42, 62.4MB/s]
#
#
# model.safetensors:  34% 1.36G/4.02G [00:27<01:09, 38.1MB/s]
#
#
# model.safetensors:  34% 1.37G/4.02G [00:27<00:57, 45.7MB/s]
#
#
# model.safetensors:  34% 1.38G/4.02G [00:28<00:48, 53.9MB/s]
#
#
# model.safetensors:  35% 1.39G/4.02G [00:28<00:44, 58.6MB/s]
#
#
# model.safetensors:  35% 1.41G/4.02G [00:28<00:48, 54.2MB/s]
#
#
# model.safetensors:  35% 1.42G/4.02G [00:28<00:46, 55.7MB/s]
#
#
# model.safetensors:  35% 1.43G/4.02G [00:28<00:41, 62.3MB/s]
#
#
# model.safetensors:  36% 1.44G/4.02G [00:29<00:59, 43.3MB/s]
#
#
# model.safetensors:  36% 1.46G/4.02G [00:29<00:43, 58.3MB/s]
#
#
# model.safetensors:  36% 1.47G/4.02G [00:29<00:40, 62.5MB/s]
#
#
# model.safetensors:  37% 1.48G/4.02G [00:29<00:50, 50.8MB/s]
#
#
# model.safetensors:  37% 1.49G/4.02G [00:30<00:54, 46.6MB/s]
#
#
# model.safetensors:  37% 1.50G/4.02G [00:30<00:56, 44.6MB/s]
#
#
# model.safetensors:  38% 1.51G/4.02G [00:30<00:48, 51.3MB/s]
#
#
# model.safetensors:  38% 1.52G/4.02G [00:30<00:44, 56.8MB/s]
#
#
# model.safetensors:  38% 1.53G/4.02G [00:30<00:39, 63.5MB/s]
#
#
# model.safetensors:  38% 1.54G/4.02G [00:30<00:45, 54.9MB/s]
#
#
# model.safetensors:  39% 1.55G/4.02G [00:31<00:48, 51.0MB/s]
#
#
# model.safetensors:  39% 1.56G/4.02G [00:31<00:46, 53.1MB/s]
#
#
# model.safetensors:  39% 1.57G/4.02G [00:31<00:51, 48.0MB/s]
#
#
# model.safetensors:  39% 1.58G/4.02G [00:31<00:43, 56.6MB/s]
#
#
# model.safetensors:  40% 1.59G/4.02G [00:32<00:50, 48.4MB/s]
#
#
# model.safetensors:  40% 1.60G/4.02G [00:32<00:46, 51.7MB/s]
#
#
# model.safetensors:  40% 1.61G/4.02G [00:32<00:50, 48.0MB/s]
#
#
# model.safetensors:  40% 1.63G/4.02G [00:32<00:45, 52.4MB/s]
#
#
# model.safetensors:  41% 1.64G/4.02G [00:32<00:46, 51.4MB/s]
#
#
# model.safetensors:  41% 1.65G/4.02G [00:32<00:40, 59.0MB/s]
#
#
# model.safetensors:  41% 1.66G/4.02G [00:33<00:38, 61.3MB/s]
#
#
# model.safetensors:  41% 1.67G/4.02G [00:33<00:37, 62.3MB/s]
#
#
# model.safetensors:  42% 1.68G/4.02G [00:33<00:34, 67.6MB/s]
#
#
# model.safetensors:  42% 1.69G/4.02G [00:33<00:33, 69.5MB/s]
#
#
# model.safetensors:  42% 1.70G/4.02G [00:33<00:31, 74.9MB/s]
#
#
# model.safetensors:  42% 1.71G/4.02G [00:33<00:29, 78.5MB/s]
#
#
# model.safetensors:  43% 1.72G/4.02G [00:33<00:28, 80.7MB/s]
#
#
# model.safetensors:  43% 1.73G/4.02G [00:34<00:31, 73.1MB/s]
#
#
# model.safetensors:  43% 1.74G/4.02G [00:34<00:29, 77.7MB/s]
#
#
# model.safetensors:  44% 1.75G/4.02G [00:34<00:32, 70.1MB/s]
#
#
# model.safetensors:  44% 1.76G/4.02G [00:34<00:34, 66.2MB/s]
#
#
# model.safetensors:  44% 1.77G/4.02G [00:34<00:31, 71.9MB/s]
#
#
# model.safetensors:  44% 1.78G/4.02G [00:34<00:34, 64.8MB/s]
#
#
# model.safetensors:  45% 1.79G/4.02G [00:35<00:49, 44.7MB/s]
#
#
# model.safetensors:  45% 1.80G/4.02G [00:35<00:42, 51.8MB/s]
#
#
# model.safetensors:  45% 1.81G/4.02G [00:35<00:46, 47.3MB/s]
#
#
# model.safetensors:  45% 1.82G/4.02G [00:35<00:43, 50.5MB/s]
#
#
# model.safetensors:  46% 1.84G/4.02G [00:36<00:49, 44.3MB/s]
#
#
# model.safetensors:  46% 1.85G/4.02G [00:36<00:45, 48.1MB/s]
#
#
# model.safetensors:  46% 1.86G/4.02G [00:36<00:42, 51.0MB/s]
#
#
# model.safetensors:  46% 1.87G/4.02G [00:36<00:41, 52.1MB/s]
#
#
# model.safetensors:  47% 1.88G/4.02G [00:36<00:44, 48.0MB/s]
#
#
# model.safetensors:  47% 1.89G/4.02G [00:37<00:43, 49.2MB/s]
#
#
# model.safetensors:  47% 1.90G/4.02G [00:37<00:39, 54.2MB/s]
#
#
# model.safetensors:  47% 1.91G/4.02G [00:37<00:38, 55.4MB/s]
#
#
# model.safetensors:  48% 1.92G/4.02G [00:37<00:33, 62.0MB/s]
#
#
# model.safetensors:  48% 1.93G/4.02G [00:37<00:42, 49.2MB/s]
#
#
# model.safetensors:  48% 1.94G/4.02G [00:38<00:41, 50.4MB/s]
#
#
# model.safetensors:  48% 1.95G/4.02G [00:38<00:35, 57.8MB/s]
#
#
# model.safetensors:  49% 1.96G/4.02G [00:38<00:37, 55.2MB/s]
#
#
# model.safetensors:  49% 1.97G/4.02G [00:38<00:37, 54.6MB/s]
#
#
# model.safetensors:  49% 1.98G/4.02G [00:38<00:32, 62.0MB/s]
#
#
# model.safetensors:  50% 1.99G/4.02G [00:38<00:34, 58.0MB/s]
#
#
# model.safetensors:  50% 2.00G/4.02G [00:39<00:39, 50.5MB/s]
#
#
# model.safetensors:  50% 2.01G/4.02G [00:39<00:34, 58.3MB/s]
#
#
# model.safetensors:  50% 2.02G/4.02G [00:39<00:38, 51.5MB/s]
#
#
# model.safetensors:  51% 2.03G/4.02G [00:39<00:33, 58.8MB/s]
#
#
# model.safetensors:  51% 2.04G/4.02G [00:39<00:29, 66.4MB/s]
#
#
# model.safetensors:  51% 2.06G/4.02G [00:39<00:27, 72.3MB/s]
#
#
# model.safetensors:  51% 2.07G/4.02G [00:40<00:25, 76.1MB/s]
#
#
# model.safetensors:  52% 2.08G/4.02G [00:40<00:24, 80.3MB/s]
#
#
# model.safetensors:  52% 2.09G/4.02G [00:40<00:25, 76.0MB/s]
#
#
# model.safetensors:  52% 2.10G/4.02G [00:40<00:26, 72.3MB/s]
#
#
# model.safetensors:  52% 2.11G/4.02G [00:40<00:25, 75.3MB/s]
#
#
# model.safetensors:  53% 2.12G/4.02G [00:41<00:44, 42.6MB/s]
#
#
# model.safetensors:  53% 2.13G/4.02G [00:41<00:37, 50.7MB/s]
#
#
# model.safetensors:  53% 2.14G/4.02G [00:41<00:36, 51.4MB/s]
#
#
# model.safetensors:  53% 2.15G/4.02G [00:41<00:31, 58.7MB/s]
#
#
# model.safetensors:  54% 2.16G/4.02G [00:41<00:28, 66.3MB/s]
#
#
# model.safetensors:  54% 2.17G/4.02G [00:41<00:32, 57.3MB/s]
#
#
# model.safetensors:  54% 2.18G/4.02G [00:42<00:30, 60.4MB/s]
#
#
# model.safetensors:  54% 2.19G/4.02G [00:42<01:08, 26.8MB/s]
#
#
# model.safetensors:  55% 2.20G/4.02G [00:43<00:53, 33.9MB/s]
#
#
# model.safetensors:  55% 2.21G/4.02G [00:43<00:48, 37.7MB/s]
#
#
# model.safetensors:  55% 2.22G/4.02G [00:43<00:39, 45.3MB/s]
#
#
# model.safetensors:  56% 2.23G/4.02G [00:43<00:43, 40.7MB/s]
#
#
# model.safetensors:  56% 2.24G/4.02G [00:43<00:45, 39.0MB/s]
#
#
# model.safetensors:  56% 2.25G/4.02G [00:44<00:46, 37.7MB/s]
#
#
# model.safetensors:  56% 2.26G/4.02G [00:44<00:40, 42.9MB/s]
#
#
# model.safetensors:  57% 2.28G/4.02G [00:44<00:40, 43.2MB/s]
#
#
# model.safetensors:  57% 2.29G/4.02G [00:44<00:33, 51.2MB/s]
#
#
# model.safetensors:  57% 2.30G/4.02G [00:45<00:40, 42.3MB/s]
#
#
# model.safetensors:  57% 2.31G/4.02G [00:45<00:55, 31.1MB/s]
#
#
# model.safetensors:  58% 2.32G/4.02G [00:45<00:43, 38.8MB/s]
#
#
# model.safetensors:  58% 2.33G/4.02G [00:45<00:39, 43.3MB/s]
#
#
# model.safetensors:  58% 2.34G/4.02G [00:46<00:50, 33.0MB/s]
#
#
# model.safetensors:  58% 2.35G/4.02G [00:46<00:43, 38.1MB/s]
#
#
# model.safetensors:  59% 2.36G/4.02G [00:46<00:44, 37.2MB/s]
#
#
# model.safetensors:  59% 2.37G/4.02G [00:47<00:40, 40.5MB/s]
#
#
# model.safetensors:  59% 2.38G/4.02G [00:47<00:33, 48.3MB/s]
#
#
# model.safetensors:  59% 2.39G/4.02G [00:47<00:30, 53.2MB/s]
#
#
# model.safetensors:  60% 2.40G/4.02G [00:47<00:31, 51.2MB/s]
#
#
# model.safetensors:  60% 2.41G/4.02G [00:48<00:40, 39.5MB/s]
#
#
# model.safetensors:  60% 2.42G/4.02G [00:48<00:37, 42.5MB/s]
#
#
# model.safetensors:  60% 2.43G/4.02G [00:48<00:41, 38.2MB/s]
#
#
# model.safetensors:  61% 2.44G/4.02G [00:48<00:34, 46.3MB/s]
#
#
# model.safetensors:  61% 2.45G/4.02G [00:48<00:28, 54.2MB/s]
#
#
# model.safetensors:  61% 2.46G/4.02G [00:49<00:47, 32.6MB/s]
#
#
# model.safetensors:  62% 2.47G/4.02G [00:49<00:38, 40.4MB/s]
#
#
# model.safetensors:  62% 2.49G/4.02G [00:49<00:39, 39.3MB/s]
#
#
# model.safetensors:  62% 2.50G/4.02G [00:49<00:32, 47.4MB/s]
#
#
# model.safetensors:  62% 2.51G/4.02G [00:50<00:28, 53.9MB/s]
#
#
# model.safetensors:  63% 2.52G/4.02G [00:50<00:25, 59.9MB/s]
#
#
# model.safetensors:  63% 2.53G/4.02G [00:50<00:23, 62.5MB/s]
#
#
# model.safetensors:  63% 2.54G/4.02G [00:50<00:24, 61.7MB/s]
#
#
# model.safetensors:  63% 2.55G/4.02G [00:50<00:21, 67.7MB/s]
#
#
# model.safetensors:  64% 2.56G/4.02G [00:50<00:19, 74.0MB/s]
#
#
# model.safetensors:  64% 2.57G/4.02G [00:50<00:18, 78.4MB/s]
#
#
# model.safetensors:  64% 2.58G/4.02G [00:51<00:24, 59.4MB/s]
#
#
# model.safetensors:  64% 2.59G/4.02G [00:51<00:23, 60.2MB/s]
#
#
# model.safetensors:  65% 2.60G/4.02G [00:51<00:22, 62.6MB/s]
#
#
# model.safetensors:  65% 2.61G/4.02G [00:51<00:27, 51.4MB/s]
#
#
# model.safetensors:  65% 2.62G/4.02G [00:51<00:23, 59.3MB/s]
#
#
# model.safetensors:  65% 2.63G/4.02G [00:52<00:27, 50.2MB/s]
#
#
# model.safetensors:  66% 2.64G/4.02G [00:52<00:23, 57.9MB/s]
#
#
# model.safetensors:  66% 2.65G/4.02G [00:52<00:20, 65.2MB/s]
#
#
# model.safetensors:  66% 2.66G/4.02G [00:52<00:22, 60.7MB/s]
#
#
# model.safetensors:  66% 2.67G/4.02G [00:52<00:27, 48.8MB/s]
#
#
# model.safetensors:  67% 2.68G/4.02G [00:53<00:23, 56.8MB/s]
#
#
# model.safetensors:  67% 2.69G/4.02G [00:53<00:24, 55.3MB/s]
#
#
# model.safetensors:  67% 2.71G/4.02G [00:53<00:21, 60.4MB/s]
#
#
# model.safetensors:  68% 2.72G/4.02G [00:53<00:19, 66.9MB/s]
#
#
# model.safetensors:  68% 2.73G/4.02G [00:53<00:17, 72.7MB/s]
#
#
# model.safetensors:  68% 2.74G/4.02G [00:53<00:16, 77.2MB/s]
#
#
# model.safetensors:  68% 2.75G/4.02G [00:53<00:15, 81.1MB/s]
#
#
# model.safetensors:  69% 2.76G/4.02G [00:53<00:15, 83.8MB/s]
#
#
# model.safetensors:  69% 2.77G/4.02G [00:54<00:16, 78.0MB/s]
#
#
# model.safetensors:  69% 2.78G/4.02G [00:54<00:15, 81.0MB/s]
#
#
# model.safetensors:  69% 2.79G/4.02G [00:54<00:15, 81.7MB/s]
#
#
# model.safetensors:  70% 2.80G/4.02G [00:54<00:14, 84.2MB/s]
#
#
# model.safetensors:  70% 2.81G/4.02G [00:54<00:14, 86.2MB/s]
#
#
# model.safetensors:  70% 2.82G/4.02G [00:55<00:25, 47.8MB/s]
#
#
# model.safetensors:  70% 2.83G/4.02G [00:55<00:22, 52.8MB/s]
#
#
# model.safetensors:  71% 2.84G/4.02G [00:55<00:21, 55.5MB/s]
#
#
# model.safetensors:  71% 2.85G/4.02G [00:55<00:24, 48.2MB/s]
#
#
# model.safetensors:  71% 2.86G/4.02G [00:55<00:20, 57.2MB/s]
#
#
# model.safetensors:  71% 2.87G/4.02G [00:55<00:17, 64.1MB/s]
#
#
# model.safetensors:  72% 2.88G/4.02G [00:55<00:16, 68.5MB/s]
#
#
# model.safetensors:  72% 2.89G/4.02G [00:56<00:15, 73.9MB/s]
#
#
# model.safetensors:  72% 2.90G/4.02G [00:56<00:15, 74.0MB/s]
#
#
# model.safetensors:  72% 2.92G/4.02G [00:56<00:21, 52.0MB/s]
#
#
# model.safetensors:  73% 2.93G/4.02G [00:56<00:19, 55.2MB/s]
#
#
# model.safetensors:  73% 2.94G/4.02G [00:57<00:23, 45.8MB/s]
#
#
# model.safetensors:  73% 2.95G/4.02G [00:57<00:25, 42.3MB/s]
#
#
# model.safetensors:  74% 2.96G/4.02G [00:57<00:21, 50.3MB/s]
#
#
# model.safetensors:  74% 2.97G/4.02G [00:57<00:18, 56.8MB/s]
#
#
# model.safetensors:  74% 2.98G/4.02G [00:57<00:19, 54.4MB/s]
#
#
# model.safetensors:  74% 2.99G/4.02G [00:58<00:19, 54.4MB/s]
#
#
# model.safetensors:  75% 3.00G/4.02G [00:58<00:18, 54.9MB/s]
#
#
# model.safetensors:  75% 3.01G/4.02G [00:58<00:20, 49.1MB/s]
#
#
# model.safetensors:  75% 3.02G/4.02G [00:58<00:26, 38.0MB/s]
#
#
# model.safetensors:  75% 3.03G/4.02G [00:59<00:27, 36.1MB/s]
#
#
# model.safetensors:  76% 3.04G/4.02G [00:59<00:25, 38.3MB/s]
#
#
# model.safetensors:  76% 3.05G/4.02G [00:59<00:24, 39.2MB/s]
#
#
# model.safetensors:  76% 3.06G/4.02G [00:59<00:20, 46.6MB/s]
#
#
# model.safetensors:  76% 3.07G/4.02G [00:59<00:17, 54.4MB/s]
#
#
# model.safetensors:  77% 3.08G/4.02G [01:00<00:15, 61.7MB/s]
#
#
# model.safetensors:  77% 3.09G/4.02G [01:00<00:22, 41.2MB/s]
#
#
# model.safetensors:  77% 3.10G/4.02G [01:00<00:25, 36.2MB/s]
#
#
# model.safetensors:  77% 3.11G/4.02G [01:01<00:22, 40.9MB/s]
#
#
# model.safetensors:  78% 3.12G/4.02G [01:01<00:19, 47.2MB/s]
#
#
# model.safetensors:  78% 3.14G/4.02G [01:01<00:28, 31.3MB/s]
#
#
# model.safetensors:  78% 3.15G/4.02G [01:02<00:25, 34.8MB/s]
#
#
# model.safetensors:  78% 3.16G/4.02G [01:02<00:22, 37.7MB/s]
#
#
# model.safetensors:  79% 3.17G/4.02G [01:02<00:18, 46.4MB/s]
#
#
# model.safetensors:  79% 3.18G/4.02G [01:02<00:22, 37.3MB/s]
#
#
# model.safetensors:  79% 3.19G/4.02G [01:02<00:20, 41.3MB/s]
#
#
# model.safetensors:  80% 3.20G/4.02G [01:03<00:16, 49.9MB/s]
#
#
# model.safetensors:  80% 3.21G/4.02G [01:03<00:18, 42.9MB/s]
#
#
# model.safetensors:  80% 3.22G/4.02G [01:03<00:20, 38.5MB/s]
#
#
# model.safetensors:  80% 3.23G/4.02G [01:03<00:17, 45.2MB/s]
#
#
# model.safetensors:  81% 3.24G/4.02G [01:04<00:18, 42.0MB/s]
#
#
# model.safetensors:  81% 3.25G/4.02G [01:04<00:20, 38.4MB/s]
#
#
# model.safetensors:  81% 3.26G/4.02G [01:04<00:16, 46.4MB/s]
#
#
# model.safetensors:  81% 3.27G/4.02G [01:04<00:17, 42.6MB/s]
#
#
# model.safetensors:  82% 3.28G/4.02G [01:04<00:14, 50.7MB/s]
#
#
# model.safetensors:  82% 3.29G/4.02G [01:05<00:13, 55.8MB/s]
#
#
# model.safetensors:  82% 3.30G/4.02G [01:05<00:15, 45.3MB/s]
#
#
# model.safetensors:  82% 3.31G/4.02G [01:05<00:18, 38.1MB/s]
#
#
# model.safetensors:  83% 3.32G/4.02G [01:06<00:17, 40.1MB/s]
#
#
# model.safetensors:  83% 3.33G/4.02G [01:06<00:17, 38.9MB/s]
#
#
# model.safetensors:  83% 3.34G/4.02G [01:06<00:14, 45.9MB/s]
#
#
# model.safetensors:  83% 3.36G/4.02G [01:06<00:14, 44.7MB/s]
#
#
# model.safetensors:  84% 3.37G/4.02G [01:06<00:13, 49.8MB/s]
#
#
# model.safetensors:  84% 3.38G/4.02G [01:07<00:13, 46.5MB/s]
#
#
# model.safetensors:  84% 3.39G/4.02G [01:07<00:11, 53.9MB/s]
#
#
# model.safetensors:  84% 3.40G/4.02G [01:07<00:13, 46.4MB/s]
#
#
# model.safetensors:  85% 3.41G/4.02G [01:07<00:16, 37.8MB/s]
#
#
# model.safetensors:  85% 3.42G/4.02G [01:08<00:13, 43.6MB/s]
#
#
# model.safetensors:  85% 3.43G/4.02G [01:08<00:15, 37.7MB/s]
#
#
# model.safetensors:  86% 3.44G/4.02G [01:08<00:13, 42.1MB/s]
#
#
# model.safetensors:  86% 3.45G/4.02G [01:08<00:14, 39.9MB/s]
#
#
# model.safetensors:  86% 3.46G/4.02G [01:09<00:12, 45.4MB/s]
#
#
# model.safetensors:  86% 3.47G/4.02G [01:09<00:12, 45.6MB/s]
#
#
# model.safetensors:  87% 3.48G/4.02G [01:09<00:10, 53.7MB/s]
#
#
# model.safetensors:  87% 3.49G/4.02G [01:09<00:12, 41.2MB/s]
#
#
# model.safetensors:  87% 3.50G/4.02G [01:10<00:12, 42.7MB/s]
#
#
# model.safetensors:  87% 3.51G/4.02G [01:10<00:12, 40.7MB/s]
#
#
# model.safetensors:  88% 3.52G/4.02G [01:10<00:16, 30.1MB/s]
#
#
# model.safetensors:  88% 3.54G/4.02G [01:11<00:11, 42.8MB/s]
#
#
# model.safetensors:  88% 3.55G/4.02G [01:11<00:13, 33.9MB/s]
#
#
# model.safetensors:  89% 3.57G/4.02G [01:11<00:11, 40.9MB/s]
#
#
# model.safetensors:  89% 3.58G/4.02G [01:12<00:12, 35.7MB/s]
#
#
# model.safetensors:  89% 3.59G/4.02G [01:12<00:10, 39.9MB/s]
#
#
# model.safetensors:  89% 3.60G/4.02G [01:12<00:09, 47.1MB/s]
#
#
# model.safetensors:  90% 3.61G/4.02G [01:12<00:07, 52.3MB/s]
#
#
# model.safetensors:  90% 3.62G/4.02G [01:13<00:11, 36.7MB/s]
#
#
# model.safetensors:  90% 3.63G/4.02G [01:13<00:08, 44.5MB/s]
#
#
# model.safetensors:  90% 3.64G/4.02G [01:13<00:09, 38.4MB/s]
#
#
# model.safetensors:  91% 3.65G/4.02G [01:13<00:10, 36.8MB/s]
#
#
# model.safetensors:  91% 3.66G/4.02G [01:14<00:08, 42.0MB/s]
#
#
# model.safetensors:  91% 3.67G/4.02G [01:14<00:07, 44.8MB/s]
#
#
# model.safetensors:  92% 3.68G/4.02G [01:14<00:08, 39.4MB/s]
#
#
# model.safetensors:  92% 3.69G/4.02G [01:14<00:09, 36.3MB/s]
#
#
# model.safetensors:  92% 3.70G/4.02G [01:15<00:08, 36.3MB/s]
#
#
# model.safetensors:  92% 3.71G/4.02G [01:15<00:07, 41.6MB/s]
#
#
# model.safetensors:  93% 3.72G/4.02G [01:15<00:06, 48.7MB/s]
#
#
# model.safetensors:  93% 3.73G/4.02G [01:15<00:05, 56.3MB/s]
#
#
# model.safetensors:  93% 3.74G/4.02G [01:15<00:04, 59.1MB/s]
#
#
# model.safetensors:  93% 3.75G/4.02G [01:15<00:04, 64.3MB/s]
#
#
# model.safetensors:  94% 3.76G/4.02G [01:16<00:06, 38.1MB/s]
#
#
# model.safetensors:  94% 3.77G/4.02G [01:16<00:06, 38.7MB/s]
#
#
# model.safetensors:  94% 3.79G/4.02G [01:16<00:05, 42.9MB/s]
#
#
# model.safetensors:  94% 3.80G/4.02G [01:17<00:04, 50.6MB/s]
#
#
# model.safetensors:  95% 3.81G/4.02G [01:17<00:03, 56.8MB/s]
#
#
# model.safetensors:  95% 3.82G/4.02G [01:17<00:03, 59.7MB/s]
#
#
# model.safetensors:  95% 3.83G/4.02G [01:17<00:04, 45.6MB/s]
#
#
# model.safetensors:  95% 3.84G/4.02G [01:18<00:04, 41.4MB/s]
#
#
# model.safetensors:  96% 3.85G/4.02G [01:18<00:04, 39.8MB/s]
#
#
# model.safetensors:  96% 3.86G/4.02G [01:18<00:04, 39.8MB/s]
#
#
# model.safetensors:  96% 3.87G/4.02G [01:18<00:03, 47.9MB/s]
#
#
# model.safetensors:  96% 3.88G/4.02G [01:18<00:02, 50.0MB/s]
#
#
# model.safetensors:  97% 3.89G/4.02G [01:18<00:02, 57.7MB/s]
#
#
# model.safetensors:  97% 3.90G/4.02G [01:19<00:02, 58.6MB/s]
#
#
# model.safetensors:  97% 3.91G/4.02G [01:19<00:02, 47.7MB/s]
#
#
# model.safetensors:  97% 3.92G/4.02G [01:20<00:03, 30.7MB/s]
#
#
# model.safetensors:  98% 3.93G/4.02G [01:20<00:02, 35.3MB/s]
#
#
# model.safetensors:  98% 3.94G/4.02G [01:21<00:03, 21.6MB/s]
#
#
# model.safetensors:  98% 3.95G/4.02G [01:21<00:03, 22.6MB/s]
#
#
# model.safetensors:  99% 3.96G/4.02G [01:21<00:02, 28.1MB/s]
#
#
# model.safetensors:  99% 3.97G/4.02G [01:21<00:01, 35.1MB/s]
#
#
# model.safetensors:  99% 3.98G/4.02G [01:22<00:01, 37.0MB/s]
#
#
# model.safetensors:  99% 4.00G/4.02G [01:22<00:00, 38.7MB/s]
#
#
# model.safetensors: 100% 4.01G/4.02G [01:22<00:00, 44.4MB/s]
#
#
# model.safetensors: 100% 4.02G/4.02G [01:22<00:00, 48.5MB/s]
#
# Fetching 8 files: 100% 8/8 [01:23<00:00, 10.40s/it]
# Warmup loader cache: 100% 2/2 [02:20<00:00, 70.24s/it]
# Executing graph: 100% 977/977 [06:20<00:00,  2.56it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# @title ## Upload model to Hugging Face { display-mode: "form" }
# @markdown Enter your HF username and the name of Colab secret that stores your [Hugging Face access token](https://huggingface.co/settings/tokens).
username = 'mlabonne' # @param {type:"string"}
token = 'HF_TOKEN' # @param {type:"string"}
license = "apache-2.0" # @param ["apache-2.0", "cc-by-nc-4.0", "mit", "openrail"] {allow-input: true}

# !pip install -qU huggingface_hub

import yaml

from huggingface_hub import ModelCard, ModelCardData, HfApi
from google.colab import userdata
from jinja2 import Template

if branch == "main":
    template_text = """
---
license: {{ license }}
base_model:
{%- for model in models %}
  - {{ model }}
{%- endfor %}
tags:
- merge
- mergekit
- lazymergekit
{%- for model in models %}
- {{ model }}
{%- endfor %}
---

# {{ model_name }}

{{ model_name }} is a merge of the following models using [LazyMergekit](https://colab.research.google.com/drive/1obulZ1ROXHjYLn6PPZJwRR6GzgQogxxb?usp=sharing):

{%- for model in models %}
* [{{ model }}](https://huggingface.co/{{ model }})
{%- endfor %}

## 🧩 Configuration

```yaml
{{- yaml_config -}}
```

## 💻 Usage

```python
# !pip install -qU transformers accelerate

from transformers import AutoTokenizer
import transformers
import torch

model = "{{ username }}/{{ model_name }}"
messages = [{"role": "user", "content": "What is a large language model?"}]

tokenizer = AutoTokenizer.from_pretrained(model)
prompt = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)

outputs = pipeline(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
```
"""

    # Create a Jinja template object
    jinja_template = Template(template_text.strip())

    # Get list of models from config
    data = yaml.safe_load(yaml_config)
    if "models" in data:
        models = [data["models"][i]["model"] for i in range(len(data["models"])) if "parameters" in data["models"][i]]
    elif "parameters" in data:
        models = [data["slices"][0]["sources"][i]["model"] for i in range(len(data["slices"][0]["sources"]))]
    elif "slices" in data:
        models = [data["slices"][i]["sources"][0]["model"] for i in range(len(data["slices"]))]
    else:
        raise Exception("No models or slices found in yaml config")

    # Fill the template
    content = jinja_template.render(
        model_name=MODEL_NAME,
        models=models,
        yaml_config=yaml_config,
        username=username,
    )

elif branch == "mixtral":
    template_text = """
---
license: {{ license }}
base_model:
{%- for model in models %}
  - {{ model }}
{%- endfor %}
tags:
- moe
- frankenmoe
- merge
- mergekit
- lazymergekit
{%- for model in models %}
- {{ model }}
{%- endfor %}
---

# {{ model_name }}

{{ model_name }} is a Mixture of Experts (MoE) made with the following models using [LazyMergekit](https://colab.research.google.com/drive/1obulZ1ROXHjYLn6PPZJwRR6GzgQogxxb?usp=sharing):

{%- for model in models %}
* [{{ model }}](https://huggingface.co/{{ model }})
{%- endfor %}

## 🧩 Configuration

```yaml
{{- yaml_config -}}
```

## 💻 Usage

```python
# !pip install -qU transformers bitsandbytes accelerate

from transformers import AutoTokenizer
import transformers
import torch

model = "{{ username }}/{{ model_name }}"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    model_kwargs={"torch_dtype": torch.float16, "load_in_4bit": True},
)

messages = [{"role": "user", "content": "Explain what a Mixture of Experts is in less than 100 words."}]
prompt = pipeline.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
outputs = pipeline(prompt, max_new_tokens=256, do_sample=True, temperature=0.7, top_k=50, top_p=0.95)
print(outputs[0]["generated_text"])
```
"""

    # Create a Jinja template object
    jinja_template = Template(template_text.strip())

    # Fill the template
    data = yaml.safe_load(yaml_config)
    models = [model['source_model'] for model in data['experts']]

    content = jinja_template.render(
        model_name=MODEL_NAME,
        models=models,
        yaml_config=yaml_config,
        username=username,
        license=license
    )

# Save the model card
card = ModelCard(content)
card.save('merge/README.md')

# Defined in the secrets tab in Google Colab
api = HfApi(token=userdata.get(token))

# Upload merge folder
api.create_repo(
    repo_id=f"{username}/{MODEL_NAME}",
    repo_type="model",
    exist_ok=True,
)
api.upload_folder(
    repo_id=f"{username}/{MODEL_NAME}",
    folder_path="merge",
)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 7.7 MB/s eta 0:00:00
